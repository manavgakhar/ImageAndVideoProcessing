# %%
import matplotlib.pyplot as plt
from skimage.io import imread, imsave
from skimage.morphology import erosion, dilation, opening, closing, white_tophat
from skimage.morphology import black_tophat, skeletonize, convex_hull_image
from skimage.morphology import disk, square, diamond
from skimage.color import rgb2gray
from skimage.util import img_as_ubyte

# %% [markdown]
# ## Q1

# %%
im = imread('building.jpg', as_gray=True)
print(im.shape)
#im = im[...,3]
im = rgb2gray(im)
plt.imshow(im, cmap='gray')
plt.show()
# Out:
# (400, 300)

# %% [markdown]
# ## Erosion

# %%
plt.imshow(erosion(im), cmap='gray')

# %% [markdown]
# ## Dilation

# %%
plt.imshow(dilation(im), cmap='gray')

# %% [markdown]
# ## Opening

# %%
plt.imshow(opening(im), cmap='gray')

# %% [markdown]
# ## Closing

# %%
plt.imshow(closing(im), cmap='gray')

# %% [markdown]
# ## Q2

# %%
from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
from skimage.color import rgb2gray
import matplotlib.pylab as plt
from scipy import ndimage

# %%
im = rgb2gray(imread('Screenshot_1.jpg'))

# %%
plt.imshow(im,cmap='gray')

# %% [markdown]
# ## Opening

# %%
plt.imshow(opening(im),cmap='gray')

# %% [markdown]
# ## Closing

# %%
plt.imshow(closing(im),cmap='gray')

# %% [markdown]
# ## Opening then Closing

# %%
openn= opening(im)
open_close= closing(openn)

# %%
plt.imshow(open_close,cmap='gray')

# %% [markdown]
# ## Q3

# %%
from skimage.io import imread, imsave, imshow, show, imread_collection, imshow_collection
from skimage import color, viewer, exposure, img_as_float, data
from skimage.color import rgb2gray
from skimage.morphology import binary_opening, binary_closing, disk
from skimage.morphology import disk, square
import matplotlib.pylab as plt
from scipy import ndimage

# %%
im = rgb2gray(imread('Screenshot_2.jpg'))

# %%
plt.imshow(im,cmap='gray')

# %%
openn= opening(im)
open_close= closing(openn)

# %% [markdown]
# ## Opening and closing of the image

# %%
plt.imshow(open_close,cmap='gray')
