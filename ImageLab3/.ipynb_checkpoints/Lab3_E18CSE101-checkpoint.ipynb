# %%
from PIL import Image
import numpy as np

# %%
img= Image.open("image2.jpg")

# %%
arr= np.array(img)

# %% [markdown]
# ## Image as array

# %%
arr
# Out:
# array([[[133,  10,  28],
#         [152,  27,  45],
#         [157,  31,  52],
#         ...,
#         [142,  16,  40],
#         [146,  13,  42],
#         [153,  18,  48]],
#
#        [[144,  18,  39],
#         [177,  51,  72],
#         [177,  51,  72],
#         ...,
#         [140,  11,  39],
#         [145,  12,  43],
#         [140,   2,  36]],
#
#        [[151,  25,  47],
#         [186,  60,  82],
#         [147,  21,  43],
#         ...,
#         [135,   4,  36],
#         [141,   5,  43],
#         [152,  13,  54]],
#
#        ...,
#
#        [[ 10,   0,   6],
#         [ 31,  18,  27],
#         [ 21,  10,  16],
#         ...,
#         [ 20,  22,  37],
#         [  6,   9,  26],
#         [ 12,  15,  32]],
#
#        [[ 13,   0,   9],
#         [ 24,  11,  20],
#         [ 20,   9,  15],
#         ...,
#         [ 17,  19,  34],
#         [  0,   1,  19],
#         [  6,   9,  26]],
#
#        [[ 24,  11,  20],
#         [ 10,   0,   6],
#         [ 43,  32,  38],
# ...

# %% [markdown]
# ## Converting Array to PIL Image object

# %%
img_pil= Image.fromarray(arr)

# %%
img_pil
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x25F2685C1C8>

# %% [markdown]
# ## Format conversion

# %%
img_jpeg= Image.open("image2.jpg")

# %%
img_png= img_jpeg.save("image.png")

# %%
png= Image.open("image.png")

# %%
png
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x25F26968E88>

# %% [markdown]
# ## Cropping Images

# %%
## Using PIL
im_crop= img.crop((100,200,100,200))

# %%
im_crop
# Out:
# --------------------
# AttributeErrorTraceback (most recent call last)
# ~\anaconda3\lib\site-packages\PIL\ImageFile.py in _save(im, fp, tile, bufsize)
#     495     try:
# --> 496         fh = fp.fileno()
#     497         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# SystemErrorTraceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in _repr_png_(self)
#     641         """
#     642         b = io.BytesIO()
# --> 643         self.save(b, "PNG")
#     644         return b.getvalue()
#     645
#
# ...
