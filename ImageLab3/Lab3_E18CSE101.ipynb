# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
img= Image.open("image2.jpg")

# %%
arr= np.array(img)

# %%
arr.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ## Image as array

# %%
arr
# Out:
# array([[[133,  10,  28],
#         [152,  27,  45],
#         [157,  31,  52],
#         ...,
#         [142,  16,  40],
#         [146,  13,  42],
#         [153,  18,  48]],
#
#        [[144,  18,  39],
#         [177,  51,  72],
#         [177,  51,  72],
#         ...,
#         [140,  11,  39],
#         [145,  12,  43],
#         [140,   2,  36]],
#
#        [[151,  25,  47],
#         [186,  60,  82],
#         [147,  21,  43],
#         ...,
#         [135,   4,  36],
#         [141,   5,  43],
#         [152,  13,  54]],
#
#        ...,
#
#        [[ 10,   0,   6],
#         [ 31,  18,  27],
#         [ 21,  10,  16],
#         ...,
#         [ 20,  22,  37],
#         [  6,   9,  26],
#         [ 12,  15,  32]],
#
#        [[ 13,   0,   9],
#         [ 24,  11,  20],
#         [ 20,   9,  15],
#         ...,
#         [ 17,  19,  34],
#         [  0,   1,  19],
#         [  6,   9,  26]],
#
#        [[ 24,  11,  20],
#         [ 10,   0,   6],
#         [ 43,  32,  38],
# ...

# %% [markdown]
# ## Converting Array to PIL Image object

# %%
img_pil= Image.fromarray(arr)

# %%
img_pil
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x25F2685C1C8>

# %% [markdown]
# ## Format conversion

# %%
img_jpeg= Image.open("image2.jpg")

# %%
img_png= img_jpeg.save("image.png")

# %%
png= Image.open("image.png")

# %%
png
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x25F26968E88>

# %% [markdown]
# ## Cropping Images

# %% [markdown]
# ### Using PIL

# %%
width, height = img.size 
  
# Setting the points for cropped image 
left = 5
top = height / 4
right = 164
bottom = 3 * height / 4

# %%
img.crop((left, top, right, bottom))
# Out:
# <PIL.Image.Image image mode=RGB size=159x256 at 0x25F27B99188>

# %% [markdown]
# ### Using arrays

# %%
cropped_slice= arr[128:384,5:164]

# %%
plt.imshow(cropped_slice)

# %% [markdown]
# ## Negative of an Image

# %%
import cv2

# %%
og= cv2.imread("image2.jpg")

# %%
og=cv2.cvtColor(og,cv2.COLOR_BGR2RGB)

# %%
og_neg= 255-og

# %%
fig,axes= plt.subplots(1,2)
axes[0].imshow(og)
axes[1].imshow(og_neg)

# %% [markdown]
# ## Circular mask on input image

# %%
mask=np.zeros(512*512*3).reshape((512,512,3))

# %%
center= mask.shape[0]//2

# %%
import matplotlib.pyplot as plt
from skimage import draw
arr = np.zeros((512, 512,3))
# Create an outer and inner circle. Then subtract the inner from the outer.
radius = 512//2

ri, ci = draw.circle(512//2, 512//2, radius=radius, shape=arr.shape)
arr[ri, ci] = 1
plt.imshow(arr)
plt.show()

# %%
src = img

print(mask.dtype, mask.min(), mask.max())
# uint8 0 255

arr2 = arr2 / 255

dst = src * arr

plt.imshow(dst.astype(np.uint8))
# Out:
# float64 0.0 0.0

# %%
## Reading and displaying multiple images
import os
i= [x for x in os.listdir()]

# %%
i=i[2:-1]

# %%
i
# Out:
# ['image1.jpg', 'image2.jpg']

# %%
for j in i:
    imgg= cv2.imread(j)
    plt.imshow(imgg)
    plt.show()

# %% [markdown]
# ## Creating Thumbnail

# %%
from PIL import Image, ImageDraw, ImageFilter

# %%
im1 = Image.open('image1.jpg')
im2 = cv2.imread('image1.jpg')
im2=cv2.cvtColor(im2,cv2.COLOR_BGR2RGB)

# %%
im2= cv2.resize(im2,None,fx = 0.3, fy = 0.3)

# %%
im2.shape
# Out:
# (154, 154, 3)

# %%
im2_pil= Image.fromarray(im2)

# %%
back_im = im1.copy()
back_im.paste(im2_pil)
back_im.save('paste_pos.jpg', quality=95)

# %%
im3 = Image.open('paste_pos.jpg')

# %%
im3
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x25F2C55BDC8>
