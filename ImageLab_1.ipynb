# %%
from PIL import Image
import numpy as np

# %% [markdown]
# ## Using PIL

# %%
img= Image.open("dcLogo.JPG")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=234x213 at 0x25BCCDF9588>

# %%
img= np.array(img)

# %%
print("Height = ",img.shape[0])
print("Width = ",img.shape[1])
# Out:
# Height =  213
# Width =  234

# %% [markdown]
# ## Using Matplotlib

# %%
from matplotlib import image

# %%
img= image.imread("dcLogo.JPG")

# %%
plt.imshow(img)

# %%
print("Height = ",img.shape[0])
print("Width = ",img.shape[1])
# Out:
# Height =  213
# Width =  234

# %% [markdown]
# ## Using Skimage

# %%
from skimage.io import imread, imshow
from skimage import data

image = imread("dcLogo.JPG")
imshow(image)

# %%
print("Height = ",image.shape[0])
print("Width = ",image.shape[1])
# Out:
# Height =  213
# Width =  234

# %% [markdown]
# ## Using pure Numpy

# %%
import numpy as np

rows = 512
cols = 512

# %%
fin = open('lena_gray.raw')
print(fin)
# Out:
# <_io.TextIOWrapper name='lena_gray.raw' mode='r' encoding='cp1252'>

# %%
img = np.fromfile(fin, dtype = np.uint8, count = rows * cols)

# %%
img.shape= (img.size//cols, cols)

# %%
img
# Out:
# array([[160, 160, 160, ..., 169, 154, 129],
#        [161, 160, 159, ..., 168, 154, 129],
#        [160, 161, 160, ..., 168, 154, 129],
#        ...,
#        [ 50,  49,  55, ..., 106, 103, 104],
#        [ 49,  50,  58, ..., 107, 109, 111],
#        [ 50,  49,  59, ..., 107, 108, 112]], dtype=uint8)

# %%
plt.imshow(img,cmap='gray')

# %%
print("... Save the output image")
img.astype('int8').tofile('NewImage.raw')
print("... File successfully saved")
# Closing the file
fin.close()
# Out:
# ... Save the output image
# ... File successfully saved
